# %% [markdown]
# <a href="https://colab.research.google.com/github/tvinente/imersao-dados-CDS/blob/main/CDS_Aula_01_Coleta_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# abre a conexao com o banco de dados
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

# consulta dos dados nos banco de dados
consulta_atividade = """
SELECT *
FROM flight_activity
LIMIT 10
"""

# execucao da consulta
df_atividade = pd.read_sql_query( consulta_atividade, conn )

# fecha a conexao com o banco de dados
conn.close()

# confere se deu certo
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    dollar_cost_points_redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %% [markdown]
# # Exercícios de Coleta

# %% [markdown]
# 1. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights e
# distance da tabela “flight_activity”.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
    fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance
  FROM
    flight_activity fa
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance
# 0          100018  2017      1               3              3      1521
# 1          100102  2017      1              10             14      2030
# 2          100140  2017      1               6              6      1200
# 3          100214  2017      1               0              0         0
# 4          100272  2017      1               0              0         0

# %% [markdown]
# 2. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights e distance da tabela “flight_activity” e somente as linhas cuja coluna distance é maior do que 2000.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
    fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance
  FROM
    flight_activity fa
  WHERE
    fa.distance > 2000
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance
# 0          100102  2017      1              10             14      2030
# 1          100550  2017      1               3              3      2037
# 2          863070  2017      9               8             15      4245
# 3          100753  2017      1               8             12      3264
# 4          100816  2017      1               9             10      2340

# %% [markdown]
# 3. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights, distance, gender da tabela “flight_activity” e somente as linhas cuja coluna gender é igual a Female da tabela “flight_loyalty_history”.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
    fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance,
    flh.gender
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh ON
    (fa.loyalty_number = flh.loyalty_number)
  WHERE
    flh.gender = "Female"
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          480934  2017      1               0              0         0
# 1          480934  2017      2               3              3      2823
# 2          480934  2017      3               0              0         0
# 3          480934  2017      4               0              0         0
# 4          480934  2017      5              13             17      3757
#
#    gender
# 0  Female
# 1  Female
# 2  Female
# 3  Female
# 4  Female

# %% [markdown]
# 4. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights, distance, gender da tabela “flight_activity” e somente as linhas cuja coluna gender é igual a Female e distance maior que 2000.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
    fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance,
    flh.gender
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh ON
    (fa.loyalty_number = flh.loyalty_number)
  WHERE
    flh.gender = "Female" AND fa.distance > 200
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          480934  2017      2               3              3      2823
# 1          480934  2017      5              13             17      3757
# 2          480934  2017      6              12             12      1320
# 3          480934  2017      7               8              8      1448
# 4          480934  2017      8              14             20      2180
#
#    gender
# 0  Female
# 1  Female
# 2  Female
# 3  Female
# 4  Female

# %% [markdown]
# # Exercícios Extras

# %% [markdown]
# 1. Selecione as colunas: loyalty_number, salary, city, gender e loyalty_card da tabela “flight_activity” e “flight_loyalty_history”.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
      flh.salary,
    flh.city,
    flh.gender,
    flh.loyalty_card
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
      ON (fa.loyalty_number = flh.loyalty_number)
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number   salary          city  gender loyalty_card
# 0          100018  92552.0      Edmonton  Female       Aurora
# 1          100102      NaN       Toronto    Male         Nova
# 2          100140      NaN  Dawson Creek  Female         Nova
# 3          100214  63253.0     Vancouver    Male         Star
# 4          100272  91163.0       Toronto  Female         Star

# %% [markdown]
# 2. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights, distance, points_accumulated e somente as linhas cuja coluna distance é maior do que 2000

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance,
    fa.points_accumulated
  FROM
    flight_activity fa
  WHERE
    fa.distance > 2000
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          100102  2017      1              10             14      2030
# 1          100550  2017      1               3              3      2037
# 2          863070  2017      9               8             15      4245
# 3          100753  2017      1               8             12      3264
# 4          100816  2017      1               9             10      2340
#
#    points_accumulated
# 0               203.0
# 1               203.0
# 2               424.0
# 3               326.0
# 4               234.0

# %% [markdown]
# 3. Selecione as colunas: loyalty_number, city, gender, loyalty_card e somente as linhas cuja coluna “loyalty_card” é igual a “Star”

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    flh.city,
    flh.gender,
    flh.loyalty_card
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
        ON (fa.loyalty_number = flh.loyalty_number)
  WHERE
    flh.loyalty_card = "Star"
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number     city  gender loyalty_card
# 0          480934  Toronto  Female         Star
# 1          480934  Toronto  Female         Star
# 2          480934  Toronto  Female         Star
# 3          480934  Toronto  Female         Star
# 4          480934  Toronto  Female         Star

# %% [markdown]
# 4. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights, distance e points_accumulated e somente as linhas cuja coluna distance é maior do que 2000 e a coluna “loyalty_card” igual a “Star

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance,
    fa.points_accumulated
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
        ON (fa.loyalty_number = flh.loyalty_number)
  WHERE
    fa.distance > 2000 AND flh.loyalty_card = "Star"
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          480934  2017      2               3              3      2823
# 1          480934  2017      5              13             17      3757
# 2          480934  2017      8              14             20      2180
# 3          480934  2017     10               1              2      2676
# 4          480934  2017     11               8             14      2072
#
#    points_accumulated
# 0               282.0
# 1               375.0
# 2               218.0
# 3               267.0
# 4               207.0

# %% [markdown]
# 5. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights, distance e points_accumulated e somente as linhas cuja coluna distance é maior do que 2000 e a coluna month é igual a 9.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance,
    fa.points_accumulated
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
        ON (fa.loyalty_number = flh.loyalty_number)
  WHERE
    fa.distance > 2000 AND fa.month = 9
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          863070  2017      9               8             15      4245
# 1          691626  2018      9               8             15      4245
# 2          444931  2017      9              11             18      4428
# 3          409051  2018      9              11             18      4428
# 4          975387  2018      9              13             18      4428
#
#    points_accumulated
# 0               424.0
# 1               424.0
# 2               442.0
# 3               442.0
# 4               442.0

# %% [markdown]
# 6. Selecionar os números do cartão de fidelidade dos passeiros, a cidade e o gênero, dos passageiros que tem o cartão Star de fidelidade, mas nunca realizaram nenhuma viagem de avião ( Dica: “loyalty_card” = “Star” e “distance” = 0 )

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    flh.city,
    flh.gender,
    flh.loyalty_card
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
        ON (fa.loyalty_number = flh.loyalty_number)
  WHERE
    fa.distance = 0 AND flh.loyalty_card = "Star"
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number      city  gender loyalty_card
# 0          480934   Toronto  Female         Star
# 1          480934   Toronto  Female         Star
# 2          480934   Toronto  Female         Star
# 3          480934   Toronto  Female         Star
# 4          549612  Edmonton    Male         Star

# %% [markdown]
#  7. Selecionar os números do cartão de fidelidade, o gênero e a cidade de todos os passageiros do sexo feminino que moram na cidade de Toronto, fizeram mais de 30 viagens no total e tem o cartão de fidelidade do tipo Aurora.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    fa.total_flights,
    flh.city,
    flh.gender,
    flh.loyalty_card
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
        ON (fa.loyalty_number = flh.loyalty_number)
  WHERE
    flh.gender = "Female"
    AND flh.city = "Toronto"
    AND flh.loyalty_card = "Aurora"
"""

df_atividade = pd.read_sql_query( consulta_atividade, conn )
conn.close()
df_atividade.head()
# Out:
#    loyalty_number  total_flights     city  gender loyalty_card
# 0          929701              0  Toronto  Female       Aurora
# 1          929701              0  Toronto  Female       Aurora
# 2          929701              0  Toronto  Female       Aurora
# 3          929701              0  Toronto  Female       Aurora
# 4          929701              0  Toronto  Female       Aurora

# %% [markdown]
# 8. Selecionar os números do cartão de fidelidade, o tipo do cartão, o genero e os pontos
# acumulados, dos passageiros com salário acima de 13200, estado civil como casado e
# nível acadêmico como mestrado e número de voos agendados igual ao número total de
# voos.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect( 'database.db' )

consulta_atividade = """
  SELECT
      fa.loyalty_number,
    flh.loyalty_card,
    flh.gender,
    fa.points_accumulated
  FROM
    flight_activity fa LEFT JOIN flight_loyalty_history flh
        ON (fa.loyalty_number = flh.loyalty_number)
  WHERE
    flh.salary > 132000
    AND flh.marital_status = "Married"
    AND flh.education = "Master"
    AND ( fa.total_flights = fa.flights_booked )
"""

df_atividade = pd.read_sql_query(consulta_atividade, conn)
conn.close()
df_atividade.head()
# Out:
#    loyalty_number loyalty_card gender  points_accumulated
# 0          410982         Star   Male                 0.0
# 1          410982         Star   Male                 0.0
# 2          410982         Star   Male                 0.0
# 3          410982         Star   Male                 0.0
# 4          410982         Star   Male                 0.0
